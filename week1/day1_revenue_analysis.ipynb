# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajaydwivedi700/data-analyst-portfolio/blob/main/week1/day1_revenue_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Import pandas as pd
# Out:
#   File "/tmp/ipython-input-1084947998.py", line 1
#     Import pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
import numpy as np

# %%
'''country,quantity,unitprice,stockcode,invoiceDate,description
India,10,50,A001,2025-01-02,T-shirt
India,5,80,A002,2025-01-02,Shoes
USA,8,40,A001,2025-01-03,T-shirt
USA,4,90,A003,2025-01-03,Jeans
UK,6,70,A002,2025-01-03,Shoes
UK,2,150,A004,2025-01-04,Jacket
Germany,12,30,A001,2025-01-05,T-shirt
Germany,5,60,A002,2025-01-05,Shoes'''
# Out:
# 'country,quantity,unitprice,stockcode,invoiceDate,description\nIndia,10,50,A001,2025-01-02,T-shirt\nIndia,5,80,A002,2025-01-02,Shoes\nUSA,8,40,A001,2025-01-03,T-shirt\nUSA,4,90,A003,2025-01-03,Jeans\nUK,6,70,A002,2025-01-03,Shoes\nUK,2,150,A004,2025-01-04,Jacket\nGermany,12,30,A001,2025-01-05,T-shirt\nGermany,5,60,A002,2025-01-05,Shoes'

# %%
csv_text = '''country,quantity,unitprice,stockcode,invoiceDate,description
India,10,50,A001,2025-01-02,T-shirt
India,5,80,A002,2025-01-02,Shoes
USA,8,40,A001,2025-01-03,T-shirt
USA,4,90,A003,2025-01-03,Jeans
UK,6,70,A002,2025-01-03,Shoes
UK,2,150,A004,2025-01-04,Jacket
Germany,12,30,A001,2025-01-05,T-shirt
Germany,5,60,A002,2025-01-05,Shoes'''

with open("/content/day1_sales.csv", "w") as f:
  f.write(csv_text)

# %%
print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
df = pd.read_csv('/content/day1_sales.csv', parse_dates=['invoiceDate'])
display(df.head())
# Out:
#   country  quantity  unitprice stockcode invoiceDate description
# 0   India        10         50      A001  2025-01-02     T-shirt
# 1   India         5         80      A002  2025-01-02       Shoes
# 2     USA         8         40      A001  2025-01-03     T-shirt
# 3     USA         4         90      A003  2025-01-03       Jeans
# 4      UK         6         70      A002  2025-01-03       Shoes

# %%
# This cell is no longer needed as df.head() is displayed in the previous cell.
# display(df.head())

# %%
df['Revenue'] = df['quantity'] * df['unitprice']
display(df.head())
# Out:
#   country  quantity  unitprice stockcode invoiceDate description  Revenue
# 0   India        10         50      A001  2025-01-02     T-shirt      500
# 1   India         5         80      A002  2025-01-02       Shoes      400
# 2     USA         8         40      A001  2025-01-03     T-shirt      320
# 3     USA         4         90      A003  2025-01-03       Jeans      360
# 4      UK         6         70      A002  2025-01-03       Shoes      420
